# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from utils import load_data, clean_data
titanic = load_data('titanic.csv')
titanic
# Out:
#       pclass  survived                                  name   sex      age  \
# 1          1         1        Allison, Master. Hudson Trevor  male   0.9167
# 3          1         0  Allison, Mr. Hudson Joshua Creighton  male  30.0000
# 5          1         1                   Anderson, Mr. Harry  male  48.0000
# 7          1         0                Andrews, Mr. Thomas Jr  male  39.0000
# 9          1         0               Artagaveytia, Mr. Ramon  male  71.0000
# ...      ...       ...                                   ...   ...      ...
# 1302       3         0                     Yousif, Mr. Wazli  male      NaN
# 1303       3         0                 Yousseff, Mr. Gerious  male      NaN
# 1306       3         0             Zakarian, Mr. Mapriededer  male  26.5000
# 1307       3         0                   Zakarian, Mr. Ortin  male  27.0000
# 1308       3         0                    Zimmerman, Mr. Leo  male  29.0000
#
#       sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 1         1      2    113781  151.5500  C22 C26        S   11    NaN
# 3         1      2    113781  151.5500  C22 C26        S  NaN  135.0
# 5         0      0     19952   26.5500      E12        S    3    NaN
# 7         0      0    112050    0.0000      A36        S  NaN    NaN
# 9         0      0  PC 17609   49.5042      NaN        C  NaN   22.0
# ...     ...    ...       ...       ...      ...      ...  ...    ...
# 1302      0      0      2647    7.2250      NaN        C  NaN    NaN
# 1303      0      0      2627   14.4583      NaN        C  NaN    NaN
# 1306      0      0      2656    7.2250      NaN        C  NaN  304.0
# 1307      0      0      2670    7.2250      NaN        C  NaN    NaN
# 1308      0      0    315082    7.8750      NaN        S  NaN    NaN
#
#                             home.dest
# 1     Montreal, PQ / Chesterville, ON
# 3     Montreal, PQ / Chesterville, ON
# 5                        New York, NY
# 7                         Belfast, NI
# 9                 Montevideo, Uruguay
# ...                               ...
# 1302                              NaN
# 1303                              NaN
# 1306                              NaN
# 1307                              NaN
# 1308                              NaN
#
# [843 rows x 14 columns]

# %%
titanic.head()
# Out:
#    pclass  survived                                  name   sex      age  \
# 1       1         1        Allison, Master. Hudson Trevor  male   0.9167
# 3       1         0  Allison, Mr. Hudson Joshua Creighton  male  30.0000
# 5       1         1                   Anderson, Mr. Harry  male  48.0000
# 7       1         0                Andrews, Mr. Thomas Jr  male  39.0000
# 9       1         0               Artagaveytia, Mr. Ramon  male  71.0000
#
#    sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 1      1      2    113781  151.5500  C22 C26        S   11    NaN
# 3      1      2    113781  151.5500  C22 C26        S  NaN  135.0
# 5      0      0     19952   26.5500      E12        S    3    NaN
# 7      0      0    112050    0.0000      A36        S  NaN    NaN
# 9      0      0  PC 17609   49.5042      NaN        C  NaN   22.0
#
#                          home.dest
# 1  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 5                     New York, NY
# 7                      Belfast, NI
# 9              Montevideo, Uruguay

# %%
df_cleaned = clean_data(titanic)
print(df_cleaned.head())
# Out:
#    pclass  survived                                  name   sex  sibsp  parch  \
# 1       1         1        allison, master. hudson trevor  male      1      2
# 3       1         0  allison, mr. hudson joshua creighton  male      1      2
# 5       1         1                   anderson, mr. harry  male      0      0
# 7       1         0                andrews, mr. thomas jr  male      0      0
# 9       1         0               artagaveytia, mr. ramon  male      0      0
#
#      ticket embarked
# 1    113781        s
# 3    113781        s
# 5     19952        s
# 7    112050        s
# 9  pc 17609        c
# d:\Study\HWR Berlin\Semester 2\Enterprise Architecture for Big Data\git_kata\utils.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].str.lower()

# %%
import matplotlib.pyplot as plt

# Create bar plot
pclass_counts = df_cleaned['pclass'].value_counts().sort_index()
pclass_counts.plot(kind='bar')

plt.xlabel('Passenger Class')
plt.ylabel('Number of Passengers')
plt.title('Passenger Class Distribution')
plt.show()

# %%
titanic['age'].hist()

plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Histogram of Age')
plt.show()
